# %% [markdown]
# <a href="https://www.kaggle.com/code/ivanvitales/class-activity-4?scriptVersionId=110101675" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import matplotlib
import matplotlib.pyplot as plt
import cv2
import numpy as py

# %%
from skimage.filters import sobel
from skimage import data
from skimage import filters
from skimage import color
from skimage.filters import gaussian
from skimage import exposure
from skimage import transform
from skimage import morphology

# %%
from skimage import data
rocket_image = data.rocket()

# %%
plt.matshow(rocket_image)

# %%
from skimage import color
grayscale = color.rgb2gray(rocket_image)
rgb=color.gray2rgb(grayscale)

# %%
plt.matshow(rgb)

# %%
from PIL import Image
data = Image.open("../input/ast-image/ast.jpg");

# %%
from skimage import color 
grayscale=color.rgb2gray(data)
rgb=color.gray2rgb(grayscale)

# %%
plt.imshow(rgb, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None)

# %%
img = cv2.imread('../input/ast-image/ast.jpg')
red = img[:, :, 0]
green = img[:, :, 1]
blue = img[:, :, 2]

# %%
plt.imshow(red, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None)

# %%
plt.imshow(blue, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None)

# %%
plt.imshow(green, cmap=None, norm=None, aspect=None, interpolation=None, alpha=None, vmin=None, vmax=None, origin=None, extent=None)

# %%
red
# Out:
# array([[ 77,  76,  76, ...,   9,  63, 161],
#        [ 77,  76,  76, ...,  17,   7,  22],
#        [ 77,  76,  76, ...,  17,   7,   7],
#        ...,
#        [ 94,  93,  93, ...,  88,  87,  89],
#        [ 94,  93,  93, ...,  88,  87,  89],
#        [ 94,  93,  93, ...,  88,  87,  89]], dtype=uint8)

# %%
green
# Out:
# array([[ 53,  52,  52, ...,   3,  55, 156],
#        [ 53,  52,  52, ...,  11,   0,  17],
#        [ 53,  52,  52, ...,  11,   0,   2],
#        ...,
#        [ 75,  74,  74, ...,  74,  73,  75],
#        [ 75,  74,  74, ...,  74,  73,  75],
#        [ 75,  74,  74, ...,  74,  73,  75]], dtype=uint8)

# %%
rgb.size
# Out:
# 7986000

# %%
vertically_flipped = py.flipud(img)
plt.matshow(vertically_flipped, 'Vertically Flipped image')

# %%
thresh = 127

# %%
blurred_image = filters.gaussian(grayscale, sigma=1.0)

fig, ax = plt.subplots()
plt.imshow(blurred_image, cmap="gray")
